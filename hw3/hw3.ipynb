# %%
import pandas as pd
from sklearn import tree, metrics

# Read in dataset
df = pd.read_csv('dataset.csv')

# Subset training data
train_df = df.iloc[:200]

# Subset testing data
test_df = df.iloc[200:]

# Train model and test
model = tree.DecisionTreeClassifier(min_samples_leaf=5)
features = ["col0", "col1", "col2", "col3", "col4", "col5", "col6", "col7", "col8", "col9", "col10", "col11", "col12", "col13", "col14"]
train_X = train_df[features]
test_X = test_df[features]
model.fit(train_X, train_df.label)
predictions = model.predict(test_X)

# Calculate accuracy (Cohen's kappa, in this case)
acc = metrics.cohen_kappa_score(test_df.label, predictions)

# %%
df
# Out:
#          col0      col1      col2      col3      col4      col5      col6  \
# 0   -25.63781 -1.641582 -0.783387 -1.766548 -1.346257 -0.125099 -0.294783
# 1   -24.63781  2.237364 -0.315520  0.863190 -1.236520  1.792876 -1.586992
# 2   -25.63781  0.870826 -1.428457 -1.551454 -1.280158 -0.704865 -1.505641
# 3   -24.63781 -2.411792  0.754031  2.257638  3.516078  0.365638 -0.552951
# 4   -24.63781 -2.324099 -0.237789  1.896839  1.351780 -0.583394 -0.380177
# ..        ...       ...       ...       ...       ...       ...       ...
# 316 -24.63781 -0.425007 -1.947481  0.706192  1.464853 -0.871575 -1.713046
# 317 -24.63781  0.170333 -0.074328  2.420914 -0.081720 -0.309884  0.499204
# 318 -24.63781 -1.001040 -0.428157  2.907512  0.632031  0.884118 -0.874623
# 319 -24.63781  1.809406  0.219182  2.724558 -0.697000  0.312657 -0.496452
# 320 -24.63781 -0.511460 -0.227230  1.459096  0.323567  0.660108  1.873404
#
#          col7       col8      col9     col10      col11     col12     col13  \
# ...
